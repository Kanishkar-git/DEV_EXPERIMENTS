# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanishkar-git/DEV_EXPERIMENTS/blob/main/dev_exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create sample data
data = {
    'ID': range(1, 11),
    'Age': np.random.randint(18, 65, size=10),
    'Income': np.random.randint(30000, 90000, size=10),
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male'],
    'Education': ['High School', 'Bachelor', 'Master', 'PhD', 'Bachelor', 'Master', 'Bachelor', 'PhD', 'High School', 'Master']
}

df = pd.DataFrame(data)

# Show first rows
print("Head of DataFrame:")
print(df.head(), "\n")

# Descriptive stats
print("Descriptive Statistics:")
print(df.describe(), "\n")

# Null values
print("Null Values:")
print(df.isnull().sum(), "\n")

# Unique values
print("Unique Genders:", df['Gender'].unique())
print("Unique Education Levels:", df['Education'].unique(), "\n")

# Selecting specific columns
selected_columns = df[['Age', 'Income']]
print("Selected Columns:")
print(selected_columns.head(), "\n")

# Filter: Age > 30
filtered_data = df[df['Age'] > 30]
print("Filtered Data (Age > 30):")
print(filtered_data.head(), "\n")

# Filter: Male & Master
filtered_rows = df[(df['Gender'] == 'Male') & (df['Education'] == 'Master')]
print("Filtered Data (Male & Master):")
print(filtered_rows.head(), "\n")

# Histogram of Age
plt.hist(df['Age'], bins=5, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Boxplot of Income
plt.boxplot(df['Income'])
plt.title('Income Distribution')
plt.ylabel('Income')
plt.show()

# Bar plot of Gender counts
gender_counts = df['Gender'].value_counts()
gender_counts.plot(kind='bar', color='skyblue')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# Pie chart of Education counts
education_counts = df['Education'].value_counts()
education_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    colors=['gold', 'lightcoral', 'lightgreen', 'lightskyblue']
)
plt.title('Education Distribution')
plt.ylabel('')
plt.show()
# Out:
# Head of DataFrame:
#    ID  Age  Income  Gender    Education
# 0   1   31   59877    Male  High School
# 1   2   25   60312  Female     Bachelor
# 2   3   23   80390    Male       Master
# 3   4   22   40564  Female          PhD
# 4   5   44   64773    Male     Bachelor
#
# Descriptive Statistics:
#              ID        Age        Income
# count  10.00000  10.000000     10.000000
# mean    5.50000  33.900000  61703.400000
# std     3.02765  13.963842  15245.063538
# min     1.00000  18.000000  35840.000000
# 25%     3.25000  23.500000  54663.750000
# 50%     5.50000  29.000000  62542.500000
# 75%     7.75000  42.250000  72628.250000
# max    10.00000  59.000000  80390.000000
#
# Null Values:
# ID           0
# Age          0
# Income       0
# Gender       0
# Education    0
# dtype: int64
#
# Unique Genders: ['Male' 'Female']
# Unique Education Levels: ['High School' 'Bachelor' 'Master' 'PhD']
#
# Selected Columns:
#    Age  Income
# 0   31   59877
# 1   25   60312
# 2   23   80390
# 3   22   40564
# 4   44   64773
#
# Filtered Data (Age > 30):
#    ID  Age  Income Gender    Education
# 0   1   31   59877   Male  High School
# 4   5   44   64773   Male     Bachelor
# 6   7   59   52926   Male     Bachelor
# 8   9   37   74146   Male  High School
# 9  10   53   68075   Male       Master
#
# Filtered Data (Male & Master):
#    ID  Age  Income Gender Education
# 2   3   23   80390   Male    Master
# 9  10   53   68075   Male    Master
